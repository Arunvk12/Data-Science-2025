# %%
import pandas as pd
df=pd.DataFrame([[1,2,3],[4,3,2]],columns=['A','B','c'],index=['X ','Y'])
df
# Out:
#     A  B  c
# X   1  2  3
# Y   4  3  2

# %%
df=pd.DataFrame([[1,4,3],[6,7,8]],columns=['a','b','c'],index='X,Y'.split(','))
df
# Out:
#    a  b  c
# X  1  4  3
# Y  6  7  8

# %%
df.shape#it will tells no fo rows and columns
# Out:
# (2, 3)

# %%
df.columns#it displays the columns
# Out:
# Index(['a', 'b', 'c'], dtype='object')

# %%
df.index#it displys the rows
# Out:
# Index(['X', 'Y'], dtype='object')

# %%
df.values#it gives all the values
# Out:
# array([[1, 4, 3],
#        [6, 7, 8]])

# %%
# dicitnoary of list
data={"emp name":["RAKESH",'ARUN','HARISH'],
      "AGE":[22,22,19]
,'salary':['14l','2l','3l']}
df1=pd.DataFrame(data)
df1
# Out:
#   emp name  AGE salary
# 0   RAKESH   22    14l
# 1     ARUN   22     2l
# 2   HARISH   19     3l

# %%
#list of tuples
data=[(1,'rakesh',80),(2,'arun',100),(3,'harish',99)]
d=pd.DataFrame(data,columns=['id','name','Score'])
d
# Out:
#    id    name  Score
# 0   1  rakesh     80
# 1   2    arun    100
# 2   3  harish     99

# %%
#pd series it gives all the values in the colun way
data={"emp name":pd.Series(["RAKESH",'ARUN','HARISH']),
      "AGE":pd.Series([22,22,19])
,'salary':pd.Series(['14l','2l','3l'])}
d=pd.DataFrame(data)
d
# Out:
#   emp name  AGE salary
# 0   RAKESH   22    14l
# 1     ARUN   22     2l
# 2   HARISH   19     3l

# %%
#numpy data frame
import numpy as np
d=pd.DataFrame(np.random.randint(0,20,(3,3)),columns=['A','B','C'],index='x,y,z'.split(','))
d
# Out:
#     A  B   C
# x   5  7  12
# y  11  4  14
# z   4  4  10

# %%
df=pd.read_csv('D:\DATA SCIENCE\PYTHON\Sample - Superstore.csv',encoding='latin1')
df.head()#it gives default starting  rows
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\Dell\AppData\Local\Temp\ipykernel_7856\1947385393.py:1: SyntaxWarning: invalid escape sequence '\D'
#   df=pd.read_csv('D:\DATA SCIENCE\PYTHON\Sample - Superstore.csv',encoding='latin1')
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0    2698  CA-2016-145317  18-03-2016  23-03-2016  Standard Class    SM-20320
# 1    6827  CA-2018-118689  02-10-2018  09-10-2018  Standard Class    TC-20980
# 2    8154  CA-2019-140151  23-03-2019  25-03-2019     First Class    RB-19360
# 3    2624  CA-2019-127180  22-10-2019  24-10-2019     First Class    TA-21385
# 4    4191  CA-2019-166709  17-11-2019  22-11-2019  Standard Class    HL-15040
#
#   Customer Name      Segment Country/Region           City  ... Postal Code  \
# 0   Sean Miller  Home Office  United States   Jacksonville  ...     32216.0
# ...

# %%
df.shape
# Out:
# (9994, 21)

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country/Region', 'City',
#        'State', 'Postal Code', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=9994, step=1)

# %%
df.iloc[0:2,0:2]#it is like scling the data from the data sets
# Out:
#    Row ID        Order ID
# 0    2698  CA-2016-145317
# 1    6827  CA-2018-118689

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country/Region', 'City',
#        'State', 'Postal Code', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
df[['Order Date','Sales','Quantity']].head(10)
# Out:
#    Order Date      Sales  Quantity
# 0  18-03-2016  22638.480         6
# 1  02-10-2018  17499.950         5
# 2  23-03-2019  13999.960         4
# 3  22-10-2019  11199.968         4
# 4  17-11-2019  10499.970         3
# 5  17-12-2018   9892.740        13
# 6  23-09-2016   9449.950         5
# 7  16-04-2018   9099.930         7
# 8  02-02-2018   8749.950         5
# 9  23-05-2018   8399.976         4

# %%
df.tail(5)#it is like bottom rows and columns
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 9989    2107  US-2016-152723  26-09-2016  26-09-2016        Same Day
# 9990    4712  CA-2016-112403  31-03-2016  31-03-2016        Same Day
# 9991    8659  CA-2018-168361  21-06-2018  25-06-2018  Standard Class
# 9992    9293  CA-2019-124114  02-03-2019  02-03-2019        Same Day
# 9993    4102  US-2019-102288  19-06-2019  23-06-2019  Standard Class
#
#      Customer ID     Customer Name    Segment Country/Region          City  \
# 9989    HG-14965     Henry Goldwyn  Corporate  United States      Mesquite
# 9990    JO-15280     Jas O'Carroll   Consumer  United States  Philadelphia
# 9991    KB-16600       Ken Brennan  Corporate  United States       Chicago
# 9992    RS-19765    Roland Schwarz  Corporate  United States          Waco
# 9993    ZC-21910  Zuschuss Carroll   Consumer  United States       Houston
#
#       ... Postal Code   Region       Product ID         Category Sub-Category  \
# ...

# %%
customers = pd.DataFrame({
    "CustomerID": [1, 2, 3, 4, 5],
    "Name": ["Aarav", "Priya", "Vikram", "Meera", "Sanjay"],
    "City": ["Delhi", "Mumbai", "Bangalore", "Chennai", "Hyderabad"]
})
print(customers)
# Out:
#    CustomerID    Name       City
# 0           1   Aarav      Delhi
# 1           2   Priya     Mumbai
# 2           3  Vikram  Bangalore
# 3           4   Meera    Chennai
# 4           5  Sanjay  Hyderabad

# %%
orders = pd.DataFrame({
    "OrderID": [101, 102, 103, 104, 105],
    "CustomerID": [3, 4, 5, 6, 7],
    "Product": ["Laptop", "Phone", "Tablet", "Camera", "Printer"]
})
orders
# Out:
#    OrderID  CustomerID  Product
# 0      101           3   Laptop
# 1      102           4    Phone
# 2      103           5   Tablet
# 3      104           6   Camera
# 4      105           7  Printer

# %%
inner=pd.merge(customers,orders,on='CustomerID',how='inner')
inner
# Out:
#    CustomerID    Name       City  OrderID Product
# 0           3  Vikram  Bangalore      101  Laptop
# 1           4   Meera    Chennai      102   Phone
# 2           5  Sanjay  Hyderabad      103  Tablet

# %%
customers = pd.DataFrame({
    "CustomerID": [1, 2, 3, 3, 5],
    "Name": ["Aarav", "Priya", "Vikram", "Meera", "Sanjay"],
    "City": ["Delhi", "Mumbai", "Bangalore", "Chennai", "Hyderabad"]
})
print(customers)
# Out:
#    CustomerID    Name       City
# 0           1   Aarav      Delhi
# 1           2   Priya     Mumbai
# 2           3  Vikram  Bangalore
# 3           3   Meera    Chennai
# 4           5  Sanjay  Hyderabad

# %%
orders = pd.DataFrame({
    "OrderID": [101, 102, 103, 104, 105],
    "CustomerID": [3, 4, 5, 6, 7],
    "Product": ["Laptop", "Phone", "Tablet", "Camera", "Printer"]
})
orders
# Out:
#    OrderID  CustomerID  Product
# 0      101           3   Laptop
# 1      102           4    Phone
# 2      103           5   Tablet
# 3      104           6   Camera
# 4      105           7  Printer

# %%
inner=pd.merge(customers,orders,on='CustomerID',how='inner')
inner
# Out:
#    CustomerID    Name       City  OrderID Product
# 0           3  Vikram  Bangalore      101  Laptop
# 1           3   Meera    Chennai      101  Laptop
# 2           5  Sanjay  Hyderabad      103  Tablet

# %%
customers = pd.DataFrame({
    "CustomerID": [1, 2, 3, 3, 5],
    "Name": ["Aarav", "Priya", "Vikram", "Meera", "Sanjay"],
    "City": ["Delhi", "Mumbai", "Bangalore", "Chennai", "Hyderabad"]
})
print(customers)
# Out:
#    CustomerID    Name       City
# 0           1   Aarav      Delhi
# 1           2   Priya     Mumbai
# 2           3  Vikram  Bangalore
# 3           3   Meera    Chennai
# 4           5  Sanjay  Hyderabad

# %%
orders = pd.DataFrame({
    "OrderID": [101, 102, 103, 104, 105],
    "CustomerID": [3, 3, 5, 6, 7],
    "Product": ["Laptop", "Phone", "Tablet", "Camera", "Printer"]
})
orders
# Out:
#    OrderID  CustomerID  Product
# 0      101           3   Laptop
# 1      102           3    Phone
# 2      103           5   Tablet
# 3      104           6   Camera
# 4      105           7  Printer

# %%
inner=pd.merge(customers,orders,on='CustomerID',how='inner')
inner
# Out:
#    CustomerID    Name       City  OrderID Product
# 0           3  Vikram  Bangalore      101  Laptop
# 1           3  Vikram  Bangalore      102   Phone
# 2           3   Meera    Chennai      101  Laptop
# 3           3   Meera    Chennai      102   Phone
# 4           5  Sanjay  Hyderabad      103  Tablet
